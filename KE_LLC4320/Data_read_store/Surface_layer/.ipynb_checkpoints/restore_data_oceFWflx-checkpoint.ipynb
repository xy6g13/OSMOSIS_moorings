# %%
import os
from glob import glob
import dask
import xarray as xr
import xrft
import cartopy.crs as ccrs
from cmocean import cm
import numpy as np
from netCDF4 import Dataset
from scipy.io import loadmat

from matplotlib import pyplot as plt
# %matplotlib inline

from mitequinox.utils import *

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
# Out:
# 2025-04-20 00:59:42,755 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:34209'.
# 2025-04-20 00:59:42,758 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:37385'.
# 2025-04-20 00:59:45,022 - distributed.nanny - WARNING - Restarting worker

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:39171' processes=16 threads=128, memory=251.08 GiB>

# %% [markdown]
# # oceFWflx

# %%
# the path where (Zach's) LLC4320 data are already stored
LLC_data_folder = '/meddy/yuxlong5/data/LLC4320/'
# the path where the data will be re-stored
out_dir_nc = '/meddy/yuxlong5/data/data_store/'

# variable 
v = 'oceFWflx'

# %%
# search for right files, for example: Theta_177x201x52.*
filenames = sorted(glob(LLC_data_folder+v+'/'+v+'_177x201.*')) 
print('Number of files processed: %d' %len(filenames))

# store in netcdf files
fsize_bound = 5*1e6

for i in np.arange(len(filenames)):
#for i in np.arange(20):

    #
    file_out = out_dir_nc+'/%s_t%05d.nc'%(v, i)
          
    if not os.path.isfile(file_out) or os.path.getsize(file_out) < fsize_bound:            
        
        ds = np.fromfile(filenames[i] , dtype='>f').reshape(201,177)
        ds = np.array(ds)
        ds = xr.DataArray(ds, dims=['lat','lon'])
        ds = np.real(ds).rename(v)
        ds = ds.load() # this may be required in order to prevent pickle related errors

        #
        while True:
            try:
                ds.to_netcdf(file_out, mode='w', unlimited_dims=['time'])

            except:
                print('failure')
            break

    else:
        print('t=%d - allready processed'%(i))
# Out:
# Number of files processed: 9416

# %% [markdown]
# # 2. Add coordinates and put variables into one xarray file

# %%
filenames = sorted(glob(out_dir_nc+v+'_t*.nc')) 
print('Number of files processed: %d' %len(filenames))
# %time ds = xr.open_mfdataset(filenames, concat_dim='time', combine="nested")
print(ds)
# Out:
# Number of files processed: 9416
# CPU times: user 13 s, sys: 1.13 s, total: 14.1 s
# Wall time: 13.5 s
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 9416, lat: 201, lon: 177)
# Dimensions without coordinates: time, lat, lon
# Data variables:
#     oceFWflx  (time, lat, lon) float32 1GB dask.array<chunksize=(1, 201, 177), meta=np.ndarray>

# %%
def iters_to_date(iters, delta_t=3600.):
    t0 = datetime.datetime(2011,9,13)    
    ltime = delta_t * (np.array(iters))
    dtime = [t0+dateutil.relativedelta.relativedelta(seconds=t) for t in ltime]    
    return dtime

# %%
ds = ds.assign_coords(time=np.arange(len(filenames))*3600/86400) 
print(ds)
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 9416, lat: 201, lon: 177)
# Coordinates:
#   * time      (time) float64 75kB 0.0 0.04167 0.08333 ... 392.2 392.2 392.3
# Dimensions without coordinates: lat, lon
# Data variables:
#     oceFWflx  (time, lat, lon) float32 1GB dask.array<chunksize=(1, 201, 177), meta=np.ndarray>

# %%
chunks = {'time': 9415, 'lat': 201, 'lon': 177}
ds = ds.chunk(chunks)
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 201, lon: 177, time: 9415)
# Coordinates:
#   * time      (time) float64 0.0 0.04167 0.08333 0.125 0.1667 0.2083 0.25 ...
# Dimensions without coordinates: lat, lon
# Data variables:
#     oceFWflx  (time, lat, lon) float32 dask.array<shape=(9415, 201, 177), chunksize=(9415, 201, 177)>

# %%
out_dir_zarr = '/meddy/yuxlong5/data/data_zarr/'

file_out = out_dir_zarr+'/%s_total_rechunk.zarr'%(v)
# %time ds.to_zarr(file_out, mode='w')
# Out:
# /home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/client.py:3383: UserWarning: Sending large graph of size 10.26 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# CPU times: user 10.5 s, sys: 509 ms, total: 11 s
# Wall time: 12.5 s

# %% [markdown]
# # Read re-chunked data

# %%
out_dir_zarr = '/meddy/yuxlong5/data/data_zarr/'
ds = xr.open_zarr(out_dir_zarr+v+'_total_rechunk.zarr')
print(ds)
print('\n data size: %.1f GB' %(ds.nbytes / 1e9))
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:   (time: 9416, lat: 201, lon: 177)
# Coordinates:
#   * time      (time) float64 75kB 0.0 0.04167 0.08333 ... 392.2 392.2 392.3
# Dimensions without coordinates: lat, lon
# Data variables:
#     oceFWflx  (time, lat, lon) float32 1GB dask.array<chunksize=(1, 201, 177), meta=np.ndarray>
#
#  data size: 1.3 GB

# %%
fig = plt.figure(figsize=(24,8))
# %time ds[v].isel(lat=slice(90,100), lon=slice(90,100)).mean(dim=['lat','lon']).plot()
# Out:
# CPU times: user 8.66 s, sys: 449 ms, total: 9.11 s
# Wall time: 9.18 s

# %%
cluster.scheduler.close()
# Out:
# <coroutine object Scheduler.close at 0x7f1b913a36f0>
# 2025-04-20 00:59:42,756 - distributed.worker - WARNING - Scheduler was unaware of this worker; shutting down.
# 2025-04-20 00:59:42,758 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/comm/tcp.py", line 137, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:44968 remote=tcp://127.0.0.1:39171>: Stream is closed
# 2025-04-20 00:59:44,739 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 239, in asyncio_run
#     _cancel_all_tasks(loop)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 255, in _cancel_all_tasks
#     loop.run_until_complete(asyncio.gather(*to_cancel, return_exceptions=True))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/tornado/ioloop.py", line 699, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, f))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/tornado/ioloop.py", line 750, in _run_callback
#     ret = callback()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/tornado/ioloop.py", line 774, in _discard_future_result
#     future.result()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/tornado/ioloop.py", line 939, in _run
#     await val
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/core.py", line 1016, in send_recv
#     await comm.write(msg, serializers=serializers, on_error="raise")
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/comm/tcp.py", line 265, in write
#     frames = await to_frames(
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/comm/utils.py", line 46, in to_frames
#     msg_size = safe_sizeof(msg, default_size=-1)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/sizeof.py", line 17, in safe_sizeof
#     return sizeof(obj)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 96, in sizeof_python_dict
#     + sizeof(list(d.values()))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 59, in sizeof_python_collection
#     return sys.getsizeof(seq) + sum(map(sizeof, seq))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 96, in sizeof_python_dict
#     + sizeof(list(d.values()))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 56, in sizeof_python_collection
#     num_items / num_samples * sum(map(sizeof, samples))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 95, in sizeof_python_dict
#     + sizeof(list(d.keys()))
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/utils.py", line 772, in __call__
#     return meth(arg, *args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/dask/sizeof.py", line 59, in sizeof_python_collection
#     return sys.getsizeof(seq) + sum(map(sizeof, seq))
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2025-04-20 00:59:44,753 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-04-20 00:59:44,753 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# 2025-04-20 00:59:44,753 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2025-04-20 00:59:44,753 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2025-04-20 00:59:44,754 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-04-20 00:59:44,754 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
# KeyboardInterrupt
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,760 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-04-20 00:59:44,760 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,762 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process Dask Worker process (from Nanny):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,763 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2025-04-20 00:59:44,763 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-04-20 00:59:44,763 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,764 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,764 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# 2025-04-20 00:59:44,766 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/yuxlong5/miniconda3/envs/equinox/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
