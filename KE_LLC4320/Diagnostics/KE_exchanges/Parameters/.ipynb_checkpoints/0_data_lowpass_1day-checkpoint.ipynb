# %%
import os
from glob import glob
import numpy as np
import dask
import xarray as xr
from functools import partial
from scipy.signal import butter, filtfilt
from cmocean import cm

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from dask.distributed import Client, LocalCluster
    #
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:35395' processes=16 threads=128, memory=251.08 GiB>

# %% [markdown]
# _________
# # 1. Read dataset

# %%
out_dir_zarr = '/meddy/yuxlong5/data/data_rechunk/'

grid = xr.open_dataset('/meddy/yuxlong5/data/data_zarr/Grid.nc', decode_coords=True)
ds_U = xr.open_zarr(out_dir_zarr+'U_total_rechunk.zarr')
ds_V = xr.open_zarr(out_dir_zarr+'V_total_rechunk.zarr')
ds_W = xr.open_zarr(out_dir_zarr+'W_total_rechunk.zarr')
ds_T = xr.open_zarr(out_dir_zarr+'Theta_total_rechunk.zarr')
ds_S = xr.open_zarr(out_dir_zarr+'Salt_total_rechunk.zarr')
ds_P = xr.open_zarr(out_dir_zarr+'Pden_total_rechunk.zarr')

ds = xr.merge([ds_U,ds_V,ds_W,ds_T,ds_S,ds_P,grid])

print(ds)
print('\n data size: %.1f GB' %(ds.nbytes / 1e9))
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 9415, depth: 52, lat: 201, lon_g: 177, lat_g: 201, lon: 177)
# Coordinates: (12/21)
#   * depth    (depth) float64 0.5 1.57 2.79 4.185 ... 855.8 900.1 945.6 992.3
#   * time     (time) float64 0.0 0.04167 0.08333 0.125 ... 392.2 392.2 392.2
#   * lat      (lat) float32 47.4 47.42 47.43 47.44 ... 49.95 49.96 49.98 49.99
#   * lon_g    (lon_g) float32 -18.04 -18.02 -18.0 -17.98 ... -14.42 -14.4 -14.38
#   * lon      (lon) float32 -18.03 -18.01 -17.99 -17.97 ... -14.41 -14.39 -14.36
#   * lat_g    (lat_g) float32 47.4 47.41 47.42 47.44 ... 49.94 49.96 49.97 49.98
#     ...       ...
#     dxG      (lat_g, lon) float32 ...
#     dyG      (lat, lon_g) float32 ...
#     rA       (lat, lon) float32 ...
#     rAz      (lat_g, lon_g) float32 ...
#     rAw      (lat, lon_g) float32 ...
#     rAs      (lat_g, lon) float32 ...
# Data variables:
#     U        (time, depth, lat, lon_g) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# ...

# %% [markdown]
# # 2. Filter
#
# ## low-pass filter over 1 day

# %%
out_dir_zarr = '/meddy/yuxlong5/data/data_lowpass/'

def butter_filter(x, b, a):
    return xr.apply_ufunc(partial(filtfilt, b, a),
                          x.chunk(),
                          dask='parallelized',
                          output_dtypes=[x.dtype],
                          kwargs={'axis': 0})

# %%
lowcut = 1/24/3600

fs = 1/3600
nyq = 0.5*fs
low = lowcut/nyq

b, a = butter(4, low, 'low')

# %%
# rechunk data first
chunks = {'time': 9415, 'lat': 1, 'lon_g': 1, 'depth':52}
U = ds.U.chunk(chunks)
del U.depth.encoding['chunks']

# filter
U_filter = butter_filter(ds.U, b, a)
U_low_filter = np.real(U_filter).rename('U_low_filter')
U_low_filter = U_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat': 1, 'lon_g': 177, 'depth':1}
U_low_filter = U_low_filter.chunk(chunks)
U_low_filter = U_low_filter.drop(['dxC','dyG','rAw'])
print(U_low_filter)

# save
file_out = out_dir_zarr+'/U_1day_lowpass_filter.zarr'
# %time U_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 52, time: 9415, lat: 201, lon_g: 177)
# Coordinates:
#   * depth         (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time          (time) float64 0.0 0.04167 0.08333 0.125 ... 392.2 392.2 392.2
#   * lat           (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon_g         (lon_g) float32 -18.04 -18.02 -18.0 ... -14.42 -14.4 -14.38
# Data variables:
#     U_low_filter  (time, depth, lat, lon_g) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 31.7 s, sys: 14.3 s, total: 46 s
# Wall time: 2min 32s

# %%
# rechunk data first
chunks = {'time': 9415, 'lat_g': 1, 'lon': 1, 'depth':52}
V = ds.V.chunk(chunks)
del V.depth.encoding['chunks']

# filter
V_filter = butter_filter(ds.V, b, a)
V_low_filter = np.real(V_filter).rename('V_low_filter')
V_low_filter = V_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat_g': 1, 'lon': 177, 'depth':1}
V_low_filter = V_low_filter.chunk(chunks)
V_low_filter = V_low_filter.drop(['dxG','dyC','rAs'])
print(V_low_filter)

# save
file_out = out_dir_zarr+'/V_1day_lowpass_filter.zarr'
# %time V_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 52, time: 9415, lon: 177, lat_g: 201)
# Coordinates:
#   * depth         (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time          (time) float64 0.0 0.04167 0.08333 0.125 ... 392.2 392.2 392.2
#   * lon           (lon) float32 -18.03 -18.01 -17.99 ... -14.41 -14.39 -14.36
#   * lat_g         (lat_g) float32 47.4 47.41 47.42 47.44 ... 49.96 49.97 49.98
# Data variables:
#     V_low_filter  (time, depth, lat_g, lon) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 26.7 s, sys: 7.82 s, total: 34.5 s
# Wall time: 4min 4s

# %%
# rechunk data first
chunks = {'time': 9415, 'lat': 1, 'lon': 1, 'depth':52}
W = ds.W.chunk(chunks)
del W.depth.encoding['chunks']

# filter
W = ds.W
W_filter = butter_filter(W, b, a)
W_low_filter = np.real(W_filter).rename('W_low_filter')
W_low_filter = W_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat': 1, 'lon': 177, 'depth':1}
W_low_filter = W_low_filter.chunk(chunks)
W_low_filter = W_low_filter.drop(['XC','YC','CS','SN','Depth','rA'])
print(W_low_filter)
# save
file_out = out_dir_zarr+'/W_1day_lowpass_filter.zarr'
# %time W_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:       (depth: 52, time: 9415, lat: 201, lon: 177)
# Coordinates:
#   * depth         (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time          (time) float64 0.0 0.04167 0.08333 0.125 ... 392.2 392.2 392.2
#   * lat           (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon           (lon) float32 -18.03 -18.01 -17.99 ... -14.41 -14.39 -14.36
# Data variables:
#     W_low_filter  (time, depth, lat, lon) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 27.9 s, sys: 8.92 s, total: 36.8 s
# Wall time: 4min 14s

# %%
# rechunk data first
chunks = {'time': 9415, 'lat': 1, 'lon': 1, 'depth':52}
Theta = ds.Theta.chunk(chunks)
del Theta.depth.encoding['chunks']

# filter
Theta_filter = butter_filter(ds.Theta, b, a)
Theta_low_filter = np.real(Theta_filter).rename('Theta_low_filter')
Theta_low_filter = Theta_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat': 1, 'lon': 177, 'depth':1}
Theta_low_filter = Theta_low_filter.chunk(chunks)
Theta_low_filter = Theta_low_filter.drop(['XC','YC','CS','SN','Depth','rA'])
print(Theta_low_filter)
# save
file_out = out_dir_zarr+'/Theta_1day_lowpass_filter.zarr'
# %time Theta_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:           (depth: 52, time: 9415, lat: 201, lon: 177)
# Coordinates:
#   * depth             (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time              (time) float64 0.0 0.04167 0.08333 ... 392.2 392.2 392.2
#   * lat               (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon               (lon) float32 -18.03 -18.01 -17.99 ... -14.39 -14.36
# Data variables:
#     Theta_low_filter  (time, depth, lat, lon) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 30.8 s, sys: 13.3 s, total: 44.1 s
# Wall time: 1min 32s

# %%
# rechunk data first
chunks = {'time': 9415, 'lat': 1, 'lon': 1, 'depth':52}
Salt = ds.Salt.chunk(chunks)
del Salt.depth.encoding['chunks']

# filter
Salt_filter = butter_filter(ds.Salt, b, a)
Salt_low_filter = np.real(Salt_filter).rename('Salt_low_filter')
Salt_low_filter = Salt_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat': 1, 'lon': 177, 'depth':1}
Salt_low_filter = Salt_low_filter.chunk(chunks)
Salt_low_filter = Salt_low_filter.drop(['XC','YC','CS','SN','Depth','rA'])
print(Salt_low_filter)
# save
file_out = out_dir_zarr+'/Salt_1day_lowpass_filter.zarr'
# %time Salt_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:          (depth: 52, time: 9415, lat: 201, lon: 177)
# Coordinates:
#   * depth            (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time             (time) float64 0.0 0.04167 0.08333 ... 392.2 392.2 392.2
#   * lat              (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon              (lon) float32 -18.03 -18.01 -17.99 ... -14.41 -14.39 -14.36
# Data variables:
#     Salt_low_filter  (time, depth, lat, lon) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 29.6 s, sys: 11.9 s, total: 41.6 s
# Wall time: 3min 16s

# %%
# rechunk data first
chunks = {'time': 9415, 'lat': 1, 'lon': 1, 'depth':52}
Pden = ds.Pden.chunk(chunks)
del Pden.depth.encoding['chunks']

# filter
Pden_filter = butter_filter(ds.Pden, b, a)
Pden_low_filter = np.real(Pden_filter).rename('Pden_low_filter')
Pden_low_filter = Pden_low_filter.to_dataset()

# rechunk data again
chunks = {'time': 9415, 'lat': 1, 'lon': 177, 'depth':1}
Pden_low_filter = Pden_low_filter.chunk(chunks)
Pden_low_filter = Pden_low_filter.drop(['XC','YC','CS','SN','Depth','rA'])
print(Pden_low_filter)
# save
file_out = out_dir_zarr+'/Pden_1day_lowpass_filter.zarr'
# %time Pden_low_filter.to_zarr(file_out, mode='w')
# Out:
# <xarray.Dataset>
# Dimensions:          (depth: 52, time: 9415, lat: 201, lon: 177)
# Coordinates:
#   * depth            (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * time             (time) float64 0.0 0.04167 0.08333 ... 392.2 392.2 392.2
#   * lat              (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon              (lon) float32 -18.03 -18.01 -17.99 ... -14.41 -14.39 -14.36
# Data variables:
#     Pden_low_filter  (time, depth, lat, lon) float32 dask.array<chunksize=(9415, 1, 1, 177), meta=np.ndarray>
# CPU times: user 27.1 s, sys: 9.92 s, total: 37 s
# Wall time: 3min 30s

# %% [markdown]
# # 3. read filtered data

# %%
grid = xr.open_dataset('/meddy/yuxlong5/data/data_zarr/Grid.nc', decode_coords=True)

ds_U_lowpass = xr.open_zarr(out_dir_zarr+'U_1day_lowpass_filter.zarr')
ds_V_lowpass = xr.open_zarr(out_dir_zarr+'V_1day_lowpass_filter.zarr')
ds_W_lowpass = xr.open_zarr(out_dir_zarr+'W_1day_lowpass_filter.zarr')
ds_Theta_lowpass = xr.open_zarr(out_dir_zarr+'Theta_1day_lowpass_filter.zarr')
ds_Salt_lowpass = xr.open_zarr(out_dir_zarr+'Salt_1day_lowpass_filter.zarr')
ds_Pden_lowpass = xr.open_zarr(out_dir_zarr+'Pden_1day_lowpass_filter.zarr')

ds_filter = xr.merge([ds_U_lowpass,ds_V_lowpass,ds_W_lowpass,ds_Theta_lowpass,ds_Salt_lowpass,ds_Pden_lowpass,grid])
print(ds_filter)
print('\n data size: %.1f GB' %(ds_filter.nbytes / 1e9))
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 9415, depth: 52, lat: 201, lon_g: 177, lat_g: 201,
#                        lon: 177)
# Coordinates: (12/21)
#   * depth             (depth) float64 0.5 1.57 2.79 4.185 ... 900.1 945.6 992.3
#   * lat               (lat) float32 47.4 47.42 47.43 47.44 ... 49.96 49.98 49.99
#   * lon_g             (lon_g) float32 -18.04 -18.02 -18.0 ... -14.4 -14.38
#   * time              (time) float64 0.0 0.04167 0.08333 ... 392.2 392.2 392.2
#   * lat_g             (lat_g) float32 47.4 47.41 47.42 ... 49.96 49.97 49.98
#   * lon               (lon) float32 -18.03 -18.01 -17.99 ... -14.39 -14.36
#     ...                ...
#     dxG               (lat_g, lon) float32 ...
#     dyG               (lat, lon_g) float32 ...
#     rA                (lat, lon) float32 ...
#     rAz               (lat_g, lon_g) float32 ...
#     rAw               (lat, lon_g) float32 ...
#     rAs               (lat_g, lon) float32 ...
# Data variables:
# ...

# %%
fig = plt.figure(figsize=(12,10))

plt.subplot(311)
ds_filter.U_low_filter.isel(lat=100,lon_g=100).plot(x='time', y='depth',vmin=-0.5,vmax=0.5,cmap=cm.balance, yincrease=False)

plt.subplot(312)
ds_filter.V_low_filter.isel(lat_g=100,lon=100).plot(x='time', y='depth',vmin=-0.5,vmax=0.5,cmap=cm.balance, yincrease=False)

plt.subplot(313)
ds_filter.W_low_filter.isel(lat=100,lon=100).plot(x='time', y='depth',vmin=-0.001,vmax=0.001,cmap=cm.balance, yincrease=False)

# %%
fig = plt.figure(figsize=(12,10))

plt.subplot(311)
ds_filter.Theta_low_filter.isel(lat=100,lon=100).plot(x='time', y='depth',cmap=cm.thermal, yincrease=False)

plt.subplot(312)
ds_filter.Salt_low_filter.isel(lat=100,lon=100).plot(x='time', y='depth',cmap=cm.haline, yincrease=False)

plt.subplot(313)
ds_filter.Pden_low_filter.isel(lat=100,lon=100).plot(x='time', y='depth',cmap=cm.dense, yincrease=False)

# %%
cluster.close()
